# %%
library(dplyr)
library(class)
library(caret)
library(glm2)
library(glmnet)
library(pROC)
library(randomForest)
library(ggplot2)
library(purrr)
library(broom)
library(stringr)
library(GGally)

# %%
df <- read.csv("train.csv")

# %%
long_colnames <- names(df)
names(df) <- c(
  "age",
  "gender",
  "transgender",
  "race_ethnicity",
  "marital_status",
  "CRF",
  "phys_activity_past_week",
  "sweet_drinks_past_month",
  "fruit_past_month",
  "veg_past_month",
  "tobacco_past_30days",
  "cigarettes_per_day",
  "binge_drinking_past_30days",
  "bmi",
  "drug_use",
  "psych_distress_score",
  "disability_status",
  "pregnant",
  "medicare_coverage",
  "medical_coverage",
  "insured",
  "insurance_type_under65",
  "insurance_type_over65",
  "zipcode_type",
  "doctor_visits_past_year",
  "insurance_months_past_year",
  "poverty_level_fpl"
)

# %%
# Convert CRF 'yes'/'no' to 1/0
df$CRF <- ifelse(df$CRF == "YES", 1, 0)

# combine 'type of insurance' columns (reported in separate columns for <65 and >=65 yrs) and delete original cols
df$current_insurance_type <- ifelse(
    df$insurance_type_under65 == 'SKIPPED - AGE >= 65',
    df$insurance_type_over65, 
    df$insurance_type_under65)
df <- df %>% select(-insurance_type_under65, -insurance_type_over65)

# remove continuous outcome variable from df
df <- df %>% select(-doctor_visits_past_year)

# Convert all categorical predictor variables to factors
df[] <- lapply(df, function(x) if (is.character(x)) factor(x) else x)
#str(df) # Check the structure of the dataframe

# Convert outcome to factor
df$CRF <- factor(df$CRF, levels = c(1,0))

# Specify the binary outcome variable and predictor variables
outcome <- "CRF"
# exclude outcome variable from predictors
predictors <- names(df)[names(df) != "CRF"]

# %%
# total row count in train set
n <- nrow(df)

# Calculate proportion of positives in data
    # YES = has been diagnosed with chronic risk factor

RF <- sum(df$CRF == 1, na.rm = TRUE)
NoRF <- sum(df$CRF == 0, na.rm = TRUE)
propRF <- round(RF / n, 3)
propNoRF <- 1 - propRF # no missing data for this variable

print(paste('# with risk factor Dx: ', RF))
print(paste('# without risk factor Dx: ', NoRF))
print(paste('% with risk factor Dx: ', propRF))
print(paste('% without risk factor Dx: ', propNoRF))

# Confusion matrix and accuracy for classifier that always predicts 1

# Convert always-positive predictions to factor
predictions <- rep(1, n)
predictions <- factor(predictions, levels = c(1,0))

cat("Confusion Matrix:\n")
print(confusionMatrix(predictions, df$CRF))

# calculate accuracy
TP <- RF
TN <- 0
acc <- (TP + TN) / n
print(paste('Baseline accuracy: ', acc))
# Out:
# [1] "# with risk factor Dx:  1846"
# [1] "# without risk factor Dx:  1124"
# [1] "% with risk factor Dx:  0.622"
# [1] "% without risk factor Dx:  0.378"
# Confusion Matrix:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction    1    0
#          1 1846 1124
#          0    0    0
#
#                Accuracy : 0.6215
#                  95% CI : (0.6038, 0.639)
#     No Information Rate : 0.6215
#     P-Value [Acc > NIR] : 0.5082
#
#                   Kappa : 0
#
#  Mcnemar's Test P-Value : <2e-16
#
#             Sensitivity : 1.0000
#             Specificity : 0.0000
#          Pos Pred Value : 0.6215
#          Neg Pred Value :    NaN
#              Prevalence : 0.6215
#          Detection Rate : 0.6215
#    Detection Prevalence : 1.0000
#       Balanced Accuracy : 0.5000
#
#        'Positive' Class : 1
#
# [1] "Baseline accuracy:  0.621548821548822"

# %%
set.seed(123)  # for reproducibility
k <- 5  # number of folds
folds <- createFolds(df$CRF, k = k, list = TRUE, returnTrain = FALSE)


## Strategy 1: Logistic Regression with all covariates
# Create the formula
formula <- as.formula(paste(outcome, "~", paste(predictors, collapse = "+")))

# 5-fold CV
k <- 5

# Initialize vectors to store performance metrics
accuracies <- numeric(k)
sensitivities <- numeric(k)
specificities <- numeric(k)

# Perform k-fold cross-validation
for (i in 1:k) {
  # Split data into training and testing sets
  test_indices <- folds[[i]]
  train_data <- df[-test_indices, ]
  test_data <- df[test_indices, ]
  
  # Fit logistic regression model
  model <- glm(formula = formula, data = train_data, family = "binomial")
  
  # Make predictions on test data
  predictions <- predict(model, newdata = test_data, type = "response")
  predicted_classes <- ifelse(predictions > 0.5, 1, 0) # default threshold = 0.5
  
  # Calculate performance metrics
  confusion_matrix <- table(test_data$CRF, predicted_classes)
  accuracies[i] <- sum(diag(confusion_matrix)) / sum(confusion_matrix)
  sensitivities[i] <- confusion_matrix[2, 2] / sum(confusion_matrix[2, ])
  specificities[i] <- confusion_matrix[1, 1] / sum(confusion_matrix[1, ])
  
}

# Calculate average performance metrics
mean_accuracy <- mean(accuracies)
mean_sensitivity <- mean(sensitivities)
mean_specificity <- mean(specificities)

# Print results
cat("Logistic regression performance:", "\n")
cat("Mean Accuracy:", mean_accuracy, "\n")
cat("Mean Sensitivity:", mean_sensitivity, "\n")
cat("Mean Specificity:", mean_specificity, "\n")
# Out:
# Logistic regression performance:
# Mean Accuracy: 0.7131032
# Mean Sensitivity: 0.5150437
# Mean Specificity: 0.8336893

# %%
# Fit the logistic regression model on the entire train set
model <- glm(formula = formula, data = df, family = binomial())
# View model summary
summary(model)
# Out:
# Call:
# glm(formula = formula, family = binomial(), data = df)
#
# Coefficients: (2 not defined because of singularities)
#                                                              Estimate
# (Intercept)                                                 9.436e-01
# age26-29 YEARS                                             -2.037e-01
# age30-34 YEARS                                             -9.446e-02
# age35-39 YEARS                                             -2.714e-01
# age40-44 YEARS                                             -7.108e-01
# age45-49 YEARS                                             -9.415e-01
# age50-54 YEARS                                             -1.124e+00
# age55-59 YEARS                                             -1.227e+00
# age60-64 YEARS                                             -1.808e+00
# age65-69 YEARS                                             -2.677e+00
# age70-74 YEARS                                             -2.977e+00
# age75-79 YEARS                                             -3.418e+00
# age80-84 YEARS                                             -2.837e+00
# age85+ YEARS                                               -3.254e+00
# genderMALE                                                  7.689e-02
# transgenderPROXY SKIPPED                                   -1.061e+01
# transgenderTRANSGENDER AND GENDER EXPANSIVE                -4.016e-01
# race_ethnicityAMERICAN INDIAN/ALASKAN NATIVE ONLY, NH      -7.791e-01
# race_ethnicityASIAN ONLY, NH                                3.915e-01
# race_ethnicityHISPANIC                                      3.532e-01
# race_ethnicityOTHER/TWO OR MORE RACES                      -1.249e-02
# race_ethnicityWHITE, NON-HISPANIC (NH)                      3.313e-01
# marital_statusMARRIED                                      -7.331e-02
# marital_statusNEVER MARRIED                                 3.838e-01
# marital_statusWID/SEP/DIV                                   1.284e-01
# phys_activity_past_weekYES                                  1.278e-01
# sweet_drinks_past_month                                    -1.783e-03
# fruit_past_month                                           -1.189e-04
# veg_past_month                                              3.385e-04
# tobacco_past_30daysYES                                      6.360e-03
# cigarettes_per_day11-19 CIGARETTES                          7.398e-01
# cigarettes_per_day2-5 CIGARETTES                            7.378e-01
# cigarettes_per_day20 OR MORE                                6.730e-01
# cigarettes_per_day6-10 CIGARETTES                           7.253e-01
# cigarettes_per_dayNONE                                      6.747e-01
# binge_drinking_past_30days1 DAY                            -1.184e-01
# binge_drinking_past_30days15-21 DAYS                        3.157e-01
# binge_drinking_past_30days2 DAYS                            1.039e-01
# binge_drinking_past_30days22-29 DAYS                       -7.852e-02
# binge_drinking_past_30days3 DAYS                            1.672e-01
# binge_drinking_past_30days30 DAYS                          -1.150e-01
# binge_drinking_past_30days4 DAYS                            5.625e-01
# binge_drinking_past_30days5 DAYS                            5.902e-01
# binge_drinking_past_30days6 DAYS                            6.471e-01
# binge_drinking_past_30days7 DAYS                           -1.349e+00
# binge_drinking_past_30days8-14 DAYS                        -4.706e-01
# binge_drinking_past_30daysINAPPLICABLE                     -6.126e-02
# bmi18.5 - 22.99 (NORMAL RANGE)                             -4.864e-01
# bmi23.0 - 27.49 (OVERWEIGHT OR OBESE, WITH INCREASED RISK) -7.912e-01
# bmi27.5 OR HIGHER (OVERWEIGHT OR OBESE, WITH HIGH RISK)    -1.505e+00
# drug_useYES                                                 2.187e-01
# psych_distress_score                                       -3.431e-02
# disability_statusNOT DISABLED                               6.998e-01
# pregnantNO                                                  2.699e-01
# pregnantNOT APPLICABLE                                     -3.917e-02
# pregnantPROXY SKIPPED                                              NA
# pregnantYES                                                 5.081e-01
# medicare_coverageYES                                       -4.853e-01
# medical_coverageYES                                        -3.590e-01
# insuredYES                                                  2.022e-01
# zipcode_typeRURAL                                           1.619e-01
# zipcode_typeSUBURBAN                                        4.978e-02
# zipcode_typeURBAN                                           9.681e-02
# insurance_months_past_year                                 -7.786e-02
# poverty_level_fpl                                           4.188e-02
# current_insurance_typeMEDI-CAL (MEDICAID)                   1.670e-01
# current_insurance_typeMEDICARE                              4.852e-01
# current_insurance_typeMEDICARE + MEDI-CAL (MEDICAID)        1.352e+00
# current_insurance_typeMEDICARE + OTHER                      1.218e+00
# current_insurance_typeMEDICARE ONLY                         1.397e+00
# current_insurance_typeOTHER ONLY                            4.666e-01
# current_insurance_typeOTHER PUBLIC                          5.584e-01
# current_insurance_typePRIVATELY PURCHASED                   5.653e-02
# current_insurance_typeUNINSURED                                    NA
#                                                            Std. Error z value
# (Intercept)                                                 7.029e-01   1.342
# age26-29 YEARS                                              2.812e-01  -0.724
# age30-34 YEARS                                              2.399e-01  -0.394
# age35-39 YEARS                                              2.385e-01  -1.138
# age40-44 YEARS                                              2.330e-01  -3.051
# age45-49 YEARS                                              2.527e-01  -3.726
# age50-54 YEARS                                              2.555e-01  -4.400
# age55-59 YEARS                                              2.560e-01  -4.793
# age60-64 YEARS                                              2.577e-01  -7.013
# age65-69 YEARS                                              1.298e+00  -2.063
# age70-74 YEARS                                              1.310e+00  -2.272
# age75-79 YEARS                                              1.319e+00  -2.591
# age80-84 YEARS                                              1.323e+00  -2.143
# age85+ YEARS                                                1.317e+00  -2.470
# genderMALE                                                  1.114e-01   0.690
# transgenderPROXY SKIPPED                                    2.203e+02  -0.048
# transgenderTRANSGENDER AND GENDER EXPANSIVE                 4.285e-01  -0.937
# race_ethnicityAMERICAN INDIAN/ALASKAN NATIVE ONLY, NH       7.054e-01  -1.104
# race_ethnicityASIAN ONLY, NH                                2.383e-01   1.643
# race_ethnicityHISPANIC                                      2.071e-01   1.705
# race_ethnicityOTHER/TWO OR MORE RACES                       3.130e-01  -0.040
# race_ethnicityWHITE, NON-HISPANIC (NH)                      2.152e-01   1.540
# marital_statusMARRIED                                       1.731e-01  -0.424
# marital_statusNEVER MARRIED                                 1.738e-01   2.208
# marital_statusWID/SEP/DIV                                   1.760e-01   0.730
# phys_activity_past_weekYES                                  9.131e-02   1.399
# sweet_drinks_past_month                                     2.026e-03  -0.880
# fruit_past_month                                            1.049e-03  -0.113
# veg_past_month                                              1.158e-03   0.292
# tobacco_past_30daysYES                                      1.829e-01   0.035
# cigarettes_per_day11-19 CIGARETTES                          5.764e-01   1.283
# cigarettes_per_day2-5 CIGARETTES                            4.781e-01   1.543
# cigarettes_per_day20 OR MORE                                5.361e-01   1.255
# cigarettes_per_day6-10 CIGARETTES                           4.915e-01   1.475
# cigarettes_per_dayNONE                                      4.408e-01   1.530
# binge_drinking_past_30days1 DAY                             1.998e-01  -0.593
# binge_drinking_past_30days15-21 DAYS                        5.396e-01   0.585
# binge_drinking_past_30days2 DAYS                            3.021e-01   0.344
# binge_drinking_past_30days22-29 DAYS                        9.272e-01  -0.085
# binge_drinking_past_30days3 DAYS                            3.956e-01   0.423
# binge_drinking_past_30days30 DAYS                           5.884e-01  -0.195
# binge_drinking_past_30days4 DAYS                            4.159e-01   1.353
# binge_drinking_past_30days5 DAYS                            4.141e-01   1.425
# binge_drinking_past_30days6 DAYS                            7.314e-01   0.885
# binge_drinking_past_30days7 DAYS                            8.384e-01  -1.609
# binge_drinking_past_30days8-14 DAYS                         4.299e-01  -1.095
# binge_drinking_past_30daysINAPPLICABLE                      1.033e-01  -0.593
# bmi18.5 - 22.99 (NORMAL RANGE)                              3.344e-01  -1.454
# bmi23.0 - 27.49 (OVERWEIGHT OR OBESE, WITH INCREASED RISK)  3.296e-01  -2.400
# bmi27.5 OR HIGHER (OVERWEIGHT OR OBESE, WITH HIGH RISK)     3.295e-01  -4.568
# drug_useYES                                                 2.571e-01   0.851
# psych_distress_score                                        1.032e-02  -3.325
# disability_statusNOT DISABLED                               1.138e-01   6.150
# pregnantNO                                                  1.822e-01   1.481
# pregnantNOT APPLICABLE                                      4.467e-01  -0.088
# pregnantPROXY SKIPPED                                              NA      NA
# pregnantYES                                                 6.019e-01   0.844
# medicare_coverageYES                                        1.652e-01  -2.937
# medical_coverageYES                                         2.412e-01  -1.489
# insuredYES                                                  3.800e-01   0.532
# zipcode_typeRURAL                                           1.521e-01   1.065
# zipcode_typeSUBURBAN                                        1.474e-01   0.338
# zipcode_typeURBAN                                           1.330e-01   0.728
# insurance_months_past_year                                  3.074e-02  -2.533
# poverty_level_fpl                                           8.611e-02   0.486
# current_insurance_typeMEDI-CAL (MEDICAID)                   2.678e-01   0.623
# current_insurance_typeMEDICARE                              5.495e-01   0.883
# current_insurance_typeMEDICARE + MEDI-CAL (MEDICAID)        1.322e+00   1.023
# current_insurance_typeMEDICARE + OTHER                      1.307e+00   0.932
# current_insurance_typeMEDICARE ONLY                         1.343e+00   1.040
# current_insurance_typeOTHER ONLY                            1.354e+00   0.345
# current_insurance_typeOTHER PUBLIC                          5.553e-01   1.006
# current_insurance_typePRIVATELY PURCHASED                   2.474e-01   0.228
# current_insurance_typeUNINSURED                                    NA      NA
#                                                            Pr(>|z|)
# (Intercept)                                                0.179455
# age26-29 YEARS                                             0.468790
# age30-34 YEARS                                             0.693812
# age35-39 YEARS                                             0.255138
# age40-44 YEARS                                             0.002283 **
# age45-49 YEARS                                             0.000195 ***
# age50-54 YEARS                                             1.08e-05 ***
# age55-59 YEARS                                             1.64e-06 ***
# age60-64 YEARS                                             2.33e-12 ***
# age65-69 YEARS                                             0.039096 *
# age70-74 YEARS                                             0.023078 *
# age75-79 YEARS                                             0.009581 **
# age80-84 YEARS                                             0.032092 *
# age85+ YEARS                                               0.013523 *
# genderMALE                                                 0.490044
# transgenderPROXY SKIPPED                                   0.961567
# transgenderTRANSGENDER AND GENDER EXPANSIVE                0.348573
# race_ethnicityAMERICAN INDIAN/ALASKAN NATIVE ONLY, NH      0.269394
# race_ethnicityASIAN ONLY, NH                               0.100363
# race_ethnicityHISPANIC                                     0.088118 .
# race_ethnicityOTHER/TWO OR MORE RACES                      0.968173
# race_ethnicityWHITE, NON-HISPANIC (NH)                     0.123645
# marital_statusMARRIED                                      0.671911
# marital_statusNEVER MARRIED                                0.027273 *
# marital_statusWID/SEP/DIV                                  0.465651
# phys_activity_past_weekYES                                 0.161718
# sweet_drinks_past_month                                    0.378731
# fruit_past_month                                           0.909790
# veg_past_month                                             0.770078
# tobacco_past_30daysYES                                     0.972256
# cigarettes_per_day11-19 CIGARETTES                         0.199321
# cigarettes_per_day2-5 CIGARETTES                           0.122747
# cigarettes_per_day20 OR MORE                               0.209332
# cigarettes_per_day6-10 CIGARETTES                          0.140086
# cigarettes_per_dayNONE                                     0.125913
# binge_drinking_past_30days1 DAY                            0.553394
# binge_drinking_past_30days15-21 DAYS                       0.558428
# binge_drinking_past_30days2 DAYS                           0.730787
# binge_drinking_past_30days22-29 DAYS                       0.932513
# binge_drinking_past_30days3 DAYS                           0.672552
# binge_drinking_past_30days30 DAYS                          0.845119
# binge_drinking_past_30days4 DAYS                           0.176165
# binge_drinking_past_30days5 DAYS                           0.154064
# binge_drinking_past_30days6 DAYS                           0.376309
# binge_drinking_past_30days7 DAYS                           0.107706
# binge_drinking_past_30days8-14 DAYS                        0.273669
# binge_drinking_past_30daysINAPPLICABLE                     0.553084
# bmi18.5 - 22.99 (NORMAL RANGE)                             0.145830
# bmi23.0 - 27.49 (OVERWEIGHT OR OBESE, WITH INCREASED RISK) 0.016380 *
# bmi27.5 OR HIGHER (OVERWEIGHT OR OBESE, WITH HIGH RISK)    4.91e-06 ***
# drug_useYES                                                0.394984
# psych_distress_score                                       0.000883 ***
# disability_statusNOT DISABLED                              7.75e-10 ***
# pregnantNO                                                 0.138479
# pregnantNOT APPLICABLE                                     0.930119
# pregnantPROXY SKIPPED                                            NA
# pregnantYES                                                0.398646
# medicare_coverageYES                                       0.003314 **
# medical_coverageYES                                        0.136611
# insuredYES                                                 0.594681
# zipcode_typeRURAL                                          0.286900
# zipcode_typeSUBURBAN                                       0.735633
# zipcode_typeURBAN                                          0.466599
# insurance_months_past_year                                 0.011306 *
# poverty_level_fpl                                          0.626744
# current_insurance_typeMEDI-CAL (MEDICAID)                  0.533039
# current_insurance_typeMEDICARE                             0.377281
# current_insurance_typeMEDICARE + MEDI-CAL (MEDICAID)       0.306353
# current_insurance_typeMEDICARE + OTHER                     0.351525
# current_insurance_typeMEDICARE ONLY                        0.298306
# current_insurance_typeOTHER ONLY                           0.730291
# current_insurance_typeOTHER PUBLIC                         0.314633
# current_insurance_typePRIVATELY PURCHASED                  0.819289
# current_insurance_typeUNINSURED                                  NA
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 3940.0  on 2969  degrees of freedom
# Residual deviance: 3220.4  on 2898  degrees of freedom
# AIC: 3364.4
#
# Number of Fisher Scoring iterations: 11

# %%
test_df <- read.csv('test.csv')

long_colnames <- names(test_df)
names(test_df) <- c(
  "age",
  "gender",
  "transgender",
  "race_ethnicity",
  "marital_status",
  "CRF",
  "phys_activity_past_week",
  "sweet_drinks_past_month",
  "fruit_past_month",
  "veg_past_month",
  "tobacco_past_30days",
  "cigarettes_per_day",
  "binge_drinking_past_30days",
  "bmi",
  "drug_use",
  "psych_distress_score",
  "disability_status",
  "pregnant",
  "medicare_coverage",
  "medical_coverage",
  "insured",
  "insurance_type_under65",
  "insurance_type_over65",
  "zipcode_type",
  "doctor_visits_past_year",
  "insurance_months_past_year",
  "poverty_level_fpl"
)

# Convert CRF 'yes'/'no' to 1/0
test_df$CRF <- ifelse(test_df$CRF == "YES", 1, 0)

# combine 'type of insurance' columns (reported in separate columns for <65 and >=65 yrs) and delete original cols
test_df$current_insurance_type <- ifelse(
    test_df$insurance_type_under65 == 'SKIPPED - AGE >= 65',
    test_df$insurance_type_over65, 
    test_df$insurance_type_under65)
test_df <- test_df %>% select(-insurance_type_under65, -insurance_type_over65)

# remove continuous outcome variable from df
test_df <- test_df %>% select(-doctor_visits_past_year)

# Convert all categorical predictor variables to factors
test_df[] <- lapply(test_df, function(x) if (is.character(x)) factor(x) else x)

# Convert outcome to factor
test_df$CRF <- factor(test_df$CRF, levels = c(1,0))

# %%
predictions <- predict(model, newdata = test_df, type = "response")
predicted_classes <- ifelse(predictions > 0.5, 1, 0) # default threshold = 0.5

  # Calculate performance metrics
confusion_matrix <- table(test_df$CRF, predicted_classes)
accuracy <- sum(diag(confusion_matrix)) / sum(confusion_matrix)
cat("Logistic regression performance on test set:", "\n")
cat("Accuracy:", accuracy, "\n")
# Out:
# Logistic regression performance on test set:
# Accuracy: 0.722372

# %%
# Extract significant coefficients (p-value < 0.05)
# Summary of the model
summary_output <- summary(model)

significant_coefficients <- summary_output$coefficients[
  summary_output$coefficients[, "Pr(>|z|)"] < 0.05, 
]
print("Significant coefficients:")
print(significant_coefficients)
# Out:
# [1] "Significant coefficients:"
#                                                               Estimate
# age40-44 YEARS                                             -0.71078159
# age45-49 YEARS                                             -0.94148278
# age50-54 YEARS                                             -1.12430148
# age55-59 YEARS                                             -1.22690968
# age60-64 YEARS                                             -1.80765664
# age65-69 YEARS                                             -2.67741648
# age70-74 YEARS                                             -2.97747753
# age75-79 YEARS                                             -3.41796260
# age80-84 YEARS                                             -2.83654648
# age85+ YEARS                                               -3.25380898
# marital_statusNEVER MARRIED                                 0.38378758
# bmi23.0 - 27.49 (OVERWEIGHT OR OBESE, WITH INCREASED RISK) -0.79116643
# bmi27.5 OR HIGHER (OVERWEIGHT OR OBESE, WITH HIGH RISK)    -1.50547803
# psych_distress_score                                       -0.03431032
# disability_statusNOT DISABLED                               0.69977404
# medicare_coverageYES                                       -0.48525307
# insurance_months_past_year                                 -0.07785836
#                                                            Std. Error   z value
# age40-44 YEARS                                             0.23298908 -3.050708
# age45-49 YEARS                                             0.25268650 -3.725893
# age50-54 YEARS                                             0.25551926 -4.400066
# age55-59 YEARS                                             0.25596938 -4.793189
# age60-64 YEARS                                             0.25774817 -7.013267
# age65-69 YEARS                                             1.29771505 -2.063177
# age70-74 YEARS                                             1.31043081 -2.272136
# age75-79 YEARS                                             1.31937803 -2.590586
# age80-84 YEARS                                             1.32347496 -2.143257
# age85+ YEARS                                               1.31749959 -2.469685
# marital_statusNEVER MARRIED                                0.17384923  2.207589
# bmi23.0 - 27.49 (OVERWEIGHT OR OBESE, WITH INCREASED RISK) 0.32960596 -2.400340
# bmi27.5 OR HIGHER (OVERWEIGHT OR OBESE, WITH HIGH RISK)    0.32953987 -4.568425
# psych_distress_score                                       0.01031813 -3.325246
# disability_statusNOT DISABLED                              0.11378519  6.149957
# medicare_coverageYES                                       0.16522125 -2.936989
# insurance_months_past_year                                 0.03073639 -2.533100
#                                                                Pr(>|z|)
# age40-44 YEARS                                             2.283027e-03
# age45-49 YEARS                                             1.946252e-04
# age50-54 YEARS                                             1.082182e-05
# age55-59 YEARS                                             1.641506e-06
# age60-64 YEARS                                             2.328172e-12
# age65-69 YEARS                                             3.909577e-02
# age70-74 YEARS                                             2.307827e-02
# age75-79 YEARS                                             9.581261e-03
# age80-84 YEARS                                             3.209250e-02
# age85+ YEARS                                               1.352321e-02
# marital_statusNEVER MARRIED                                2.727297e-02
# bmi23.0 - 27.49 (OVERWEIGHT OR OBESE, WITH INCREASED RISK) 1.637984e-02
# bmi27.5 OR HIGHER (OVERWEIGHT OR OBESE, WITH HIGH RISK)    4.914040e-06
# psych_distress_score                                       8.834062e-04
# disability_statusNOT DISABLED                              7.750379e-10
# medicare_coverageYES                                       3.314154e-03
# insurance_months_past_year                                 1.130585e-02

# %%
reasonable_predictor_columns = list(
  "age",
  "gender",
  "race_ethnicity",
  "marital_status",
  "phys_activity_past_week",
  "veg_past_month",
  "cigarettes_per_day",
  "binge_drinking_past_30days",
  "bmi",
  "drug_use",
  "psych_distress_score",
  "disability_status",
  "insured",
  "doctor_visits_past_year",
  "poverty_level_fpl"
)
reasonable_predictors = predictors <- names(df)[names(df) %in% reasonable_predictor_columns]

formula_with_subset_of_coeff = as.formula(paste(outcome, "~", paste(predictors, collapse = "+")))

subset_of_coeff_model = glm(formula = formula_with_subset_of_coeff, data = df, family = binomial())

summary_output <- summary(subset_of_coeff_model)
significant_coefficients <- summary_output$coefficients[
  summary_output$coefficients[, "Pr(>|z|)"] < 0.05, 
]
print("Significant coefficients:")
print(significant_coefficients)
# Out:
# [1] "Significant coefficients:"
#                                                               Estimate
# age40-44 YEARS                                             -0.71327519
# age45-49 YEARS                                             -1.07308933
# age50-54 YEARS                                             -1.30650191
# age55-59 YEARS                                             -1.42820885
# age60-64 YEARS                                             -1.97912842
# age65-69 YEARS                                             -2.05397213
# age70-74 YEARS                                             -2.32938984
# age75-79 YEARS                                             -2.74838763
# age80-84 YEARS                                             -2.17666746
# age85+ YEARS                                               -2.65484309
# race_ethnicityASIAN ONLY, NH                                0.45817351
# race_ethnicityHISPANIC                                      0.40843956
# bmi23.0 - 27.49 (OVERWEIGHT OR OBESE, WITH INCREASED RISK) -0.77285801
# bmi27.5 OR HIGHER (OVERWEIGHT OR OBESE, WITH HIGH RISK)    -1.51288936
# psych_distress_score                                       -0.03443835
# disability_statusNOT DISABLED                               0.75804626
# insuredYES                                                 -0.66823398
#                                                            Std. Error   z value
# age40-44 YEARS                                              0.2279526 -3.129051
# age45-49 YEARS                                              0.2333670 -4.598291
# age50-54 YEARS                                              0.2252641 -5.799866
# age55-59 YEARS                                              0.2258672 -6.323224
# age60-64 YEARS                                              0.2273084 -8.706797
# age65-69 YEARS                                              0.2333087 -8.803667
# age70-74 YEARS                                              0.2440296 -9.545524
# age75-79 YEARS                                              0.2873319 -9.565202
# age80-84 YEARS                                              0.3115410 -6.986777
# age85+ YEARS                                                0.3392540 -7.825533
# race_ethnicityASIAN ONLY, NH                                0.2326373  1.969476
# race_ethnicityHISPANIC                                      0.2025270  2.016717
# bmi23.0 - 27.49 (OVERWEIGHT OR OBESE, WITH INCREASED RISK)  0.3250611 -2.377578
# bmi27.5 OR HIGHER (OVERWEIGHT OR OBESE, WITH HIGH RISK)     0.3249323 -4.656014
# psych_distress_score                                        0.0101549 -3.391305
# disability_statusNOT DISABLED                               0.1112482  6.814011
# insuredYES                                                  0.1967019 -3.397191
#                                                                Pr(>|z|)
# age40-44 YEARS                                             1.753721e-03
# age45-49 YEARS                                             4.259709e-06
# age50-54 YEARS                                             6.636784e-09
# age55-59 YEARS                                             2.561609e-10
# age60-64 YEARS                                             3.125817e-18
# age65-69 YEARS                                             1.324174e-18
# age70-74 YEARS                                             1.354217e-21
# age75-79 YEARS                                             1.119823e-21
# age80-84 YEARS                                             2.812724e-12
# age85+ YEARS                                               5.055096e-15
# race_ethnicityASIAN ONLY, NH                               4.889844e-02
# race_ethnicityHISPANIC                                     4.372505e-02
# bmi23.0 - 27.49 (OVERWEIGHT OR OBESE, WITH INCREASED RISK) 1.742676e-02
# bmi27.5 OR HIGHER (OVERWEIGHT OR OBESE, WITH HIGH RISK)    3.223899e-06
# psych_distress_score                                       6.956068e-04
# disability_statusNOT DISABLED                              9.491465e-12
# insuredYES                                                 6.808135e-04

# %%
model_fit_on_test_data <- glm(formula = formula, data = test_df, family = binomial())

summary_output <- summary(model_fit_on_test_data)
significant_coefficients <- summary_output$coefficients[
  summary_output$coefficients[, "Pr(>|z|)"] < 0.05, 
]
print("Significant coefficients:")
print(significant_coefficients)

predictions <- predict(model_fit_on_test_data, newdata = test_df, type = "response")
predicted_classes <- ifelse(predictions > 0.5, 1, 0) # default threshold = 0.5

  # Calculate performance metrics
confusion_matrix <- table(test_df$CRF, predicted_classes)
accuracy <- sum(diag(confusion_matrix)) / sum(confusion_matrix)
cat("Logistic regression performance on test set:", "\n")
cat("Accuracy:", accuracy, "\n")
# Out:
# [1] "Significant coefficients:"
#                               Estimate Std. Error   z value    Pr(>|z|)
# age60-64 YEARS             -1.06772701 0.51859710 -2.058876 0.039506141
# genderMALE                  0.51825167 0.24255718  2.136616 0.032629198
# psych_distress_score       -0.04584952 0.02128328 -2.154251 0.031220508
# pregnantNO                  0.92822265 0.39796054  2.332449 0.019677085
# insuredYES                  2.72708265 1.05203646  2.592194 0.009536596
# insurance_months_past_year -0.23053994 0.08633031 -2.670440 0.007575184
# Logistic regression performance on test set:
# Accuracy: 0.7654987
